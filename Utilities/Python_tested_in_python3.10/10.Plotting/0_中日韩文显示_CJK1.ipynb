# %% [markdown]
# 本机目前只有几个日文字体：Available Chinese fonts: ['Noto Sans CJK JP', 'Noto Sans CJK JP', 'Noto Serif CJK JP', 'Noto Serif CJK JP']

# %% [markdown]
# The following successfully imports the necessary modules:

# %% [markdown]
# 字体名称修正：你的系统中有 Noto Sans CJK SC（简体中文），而不是 Noto Sans CJK CN。SC = Simplified Chinese。

# %% [markdown]
# 这个包包含了 Noto Sans CJK 的所有变体，包括 Simplified Chinese (SC)、Traditional Chinese (TC)、Japanese 和 Korean 版本。安装完成后，您就可以在系统中使用 Noto Sans CJK SC 字体了。
#
# 如果您只想安装简体中文版本而不需要其他语言变体，上述命令仍然是最简单的方法，因为 Ubuntu 的包管理器将所有 CJK 变体打包在一起。安装后，您可以专门使用 "Noto Sans CJK SC" 这个字体名称来调用简体中文版本。
#
# 安装完成后，建议重新启动您的应用程序或系统以确保字体缓存更新。
#
#
# 完整的字体名称含义：
#
# Noto: Google 的 "No Tofu" 字体系列，旨在消除显示缺失字符时出现的 tofu（☐）符号
# Sans: 无衬线字体
# CJK: Chinese, Japanese, Korean（中日韩）
# SC: Simplified Chinese（简体中文）

# %%
# fc-list : family | grep -i "Noto.*CJK"
# Noto Sans CJK SC (简体中文)
# Noto Sans CJK TC (繁体中文)
# Noto Sans CJK JP (日文)
# Noto Sans CJK KR (韩文)
# Noto Sans CJK HK (香港中文)

# %%
# sudo apt update # 我个人坚决反对更新系统，本次也不更新
# sudo apt install -y fonts-noto-cjk # <<<======
# 不搞了，一切中文字体可以用日文字符集打印  ['Noto Sans CJK JP'] 就用这个了

# %%
import matplotlib.pyplot as plt

# 使用通用名称而不是具体变体
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.rcParams['axes.unicode_minus'] = False

# 测试
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3], [1, 4, 2])
plt.title('中文测试')
plt.xlabel('X轴标签')
plt.ylabel('Y轴标签')
plt.show()

# %% [markdown]
# 方法3：手动查找并添加字体文件
# 如果方法2不工作，请运行以下代码来找到正确的字体路径

# %%
import matplotlib.font_manager as fm
available_fonts = [f.name for f in fm.fontManager.ttflist]
noto_cjk_fonts = [font for font in available_fonts if 'Noto' in font and 'CJK' in font]
print("Available Noto CJK fonts in matplotlib:")
for font in sorted(set(noto_cjk_fonts)):
    print(f"  - {font}")
# Out:
# Available Noto CJK fonts in matplotlib:
#   - Noto Sans CJK JP
#   - Noto Serif CJK JP

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 测试
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3], [1, 4, 2])
plt.title('中文测试标题')
plt.xlabel('X轴标签')
plt.ylabel('Y轴标签')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号

# 测试
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3], [1, 4, 2])
plt.title('中文测试标题')
plt.xlabel('X轴标签')
plt.ylabel('Y轴标签')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.plot([1, 2, 3], [1, 4, 2])
plt.title('中文测试')
plt.show()

# %%
# 首先确保 dateutil 已安装（如果还没有）
# !conda install -y python-dateutil

# 重启 kernel 后运行以下代码
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings('ignore')

# 检查系统中实际可用的 CJK 字体
print("Available CJK fonts:")
cjk_fonts = []
for f in fm.fontManager.ttflist:
    if any(keyword in f.name.lower() for keyword in ['noto', 'sans', 'serif', 'cjk']):
        if f.name not in cjk_fonts:
            cjk_fonts.append(f.name)
            if len(cjk_fonts) <= 100:
                print(f"  - {f.name}")

# 正确的 matplotlib 配置（使用有效的 rc 参数）
plt.rcParams['font.sans-serif'] = [
    'Noto Sans CJK SC',    # 中文思源体（支持中文字符）
    'Noto Sans CJK JP',    # 日文思源黑体（支持中文字符）
    'Noto Serif CJK JP',   # 日文思源宋体
    'DejaVu Sans',         # 英文字体备选
    'Arial Unicode MS'     # 如果存在的话
]
plt.rcParams['axes.unicode_minus'] = False  # 正确显示负号
plt.rcParams['figure.figsize'] = [14, 10]   # 图形尺寸
plt.rcParams['figure.dpi'] = 150            # DPI 设置

# 注意：retina 格式应该在 Jupyter 中通过 magic 命令设置，而不是 rcParams
# 在 Jupyter notebook 中使用：%config InlineBackend.figure_format = 'retina'

# 测试中文显示（但根据项目规范，正式图表应使用英文）
fig, ax = plt.subplots()
ax.plot([1, 2, 3], [1, 4, 2])
ax.set_title('测试中文显示')
ax.set_xlabel('X轴')
ax.set_ylabel('Y轴')
plt.show()

# 符合项目规范的英文版本
fig2, ax2 = plt.subplots()
ax2.plot([1, 2, 3], [1, 4, 2])
ax2.set_title('Test Plot (English)')
ax2.set_xlabel('X-axis')
ax2.set_ylabel('Y-axis')
plt.show()
# Out:
# Available CJK fonts:
#   - DejaVu Sans Mono
#   - DejaVu Serif
#   - DejaVu Sans Display
#   - DejaVu Sans
#   - DejaVu Serif Display
#   - Nimbus Sans
#   - Liberation Sans
#   - Noto Sans CJK JP
#   - Noto Serif CJK JP
#   - FreeSans
#   - Noto Mono
#   - Nimbus Sans Narrow
#   - Liberation Serif
#   - RaghuMalayalamSans
#   - Droid Sans Fallback
#   - Liberation Sans Narrow
#   - FreeSerif
#   - Noto Sans Mono

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 查找系统中可用的中文字体
available_fonts = [f.name for f in fm.fontManager.ttflist if 'Noto Sans CJK' in f.name or 'Noto Serif CJK' in f.name]
print("Available Chinese fonts:", available_fonts)

# 设置中文字体（使用系统已有的 Noto Sans CJK）
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK SC', 'Noto Sans CJK TC', 'Noto Sans CJK JP', 'SimHei', 'Arial Unicode MS']
plt.rcParams['axes.unicode_minus'] = False  # 正常显示负号

# 测试中文显示
plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3], [1, 4, 2])
plt.title('测试中文标题')
plt.xlabel('X轴标签')
plt.ylabel('Y轴标签')
plt.show()
# Out:
# Available Chinese fonts: ['Noto Sans CJK JP', 'Noto Sans CJK JP', 'Noto Serif CJK JP', 'Noto Serif CJK JP']

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Replace 'Noto Sans CJK JP' with the name of a CJK-supported font on your system.
# For example, on Windows, you might use 'Microsoft YaHei'.
# Chinese Japanese and Korean fonts are supported by default in matplotlib.
# font_properties = font_manager.FontProperties(family='Noto Sans CJK CN') 
font_properties = font_manager.FontProperties(family='Noto Sans CJK SC')

plt.title("测试", fontproperties=font_properties)
plt.xlabel("测试", fontproperties=font_properties)
plt.ylabel("测试", fontproperties=font_properties)
plt.plot([1, 2, 3])
plt.show()
# Out:
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.
# findfont: Font family 'Noto Sans CJK SC' not found.

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Replace 'Noto Sans CJK JP' with the name of a CJK-supported font on your system.
# For example, on Windows, you might use 'Microsoft YaHei'.
# Chinese Japanese and Korean fonts are supported by default in matplotlib.
font_properties = font_manager.FontProperties(family='Microsoft YaHei')

plt.title("测试", fontproperties=font_properties)
plt.xlabel("测试", fontproperties=font_properties)
plt.ylabel("测试", fontproperties=font_properties)
plt.plot([1, 2, 3])
plt.show()

# %%
plt.rcParams['font.sans-serif'] = 'SimHei'     # 用来正常显示中文标签  中易黑体 office 捆绑,也有版权
# font_properties = font_manager.FontProperties(family='Microsoft YaHei') # 用来正常显示中文标签     2 选 1
# 都是商业字体
# missing from font(s) DejaVu Sans. fig.canvas.print_figure(bytes_io, **kw)  , 如果没有上句, 无法显示中文

# %% [markdown]
# 二、开源中文字体列表（2025 更新）
# 1. 黑体 / 无衬线

# %% [markdown]
# | 名称                       | 授权      | 字符集               | 特色                  |
# | ------------------------ | ------- | ----------------- | ------------------- |
# | **思源黑体** Source Han Sans | OFL-1.1 | GB18030 + CJK 全语言 | 7 字重，Adobe + Google |
# | **OPPOSans**             | OFL-1.1 | GB18030           | 屏显优化，圆角人文           |
# | **HarmonyOS Sans**       | OFL-1.1 | GB18030 + 日文      | 华为鸿蒙默认，Cleartype++  |
# | **MiSans**               | OFL-1.1 | GB18030           | 小米 13 默认，10 字重      |
# | **Alibaba PuHuiTi**      | OFL-1.1 | GB18030           | 阿里官方，3 字重           |

# %% [markdown]
# 2. 宋体 / 衬线

# %% [markdown]
# | 名称                        | 授权      | 字符集           | 特色         |
# | ------------------------- | ------- | ------------- | ---------- |
# | **思源宋体** Source Han Serif | OFL-1.1 | GB18030 + CJK | 传统宋体，7 字重  |
# | **ShipinSong**            | OFL-1.1 | GB18030       | 食品包装专用，高易读 |
# | **FandolSong**            | OFL-1.1 | GB18030       | 方正捐赠，古籍常用  |

# %% [markdown]
# 3. 手写 / 艺术

# %% [markdown]
# | 名称                        | 授权      | 字符集     | 特色        |
# | ------------------------- | ------- | ------- | --------- |
# | **MaShanZheng**           | OFL-1.1 | GB2312  | 毛笔招牌风格    |
# | **ZCOOL QingKe HuangYou** | OFL-1.1 | GB2312  | 黄油手写字体    |
# | **LXGW WenKai**           | OFL-1.1 | GB18030 | 开源文楷，毛笔质感 |

# %% [markdown]
# 4. 等宽 / 编程

# %% [markdown]
# | 名称                       | 授权      | 字符集     | 特色                     |
# | ------------------------ | ------- | ------- | ---------------------- |
# | **思源等宽** Source Han Mono | OFL-1.1 | GB18030 | 等宽版思源黑体                |
# | **LXGW Bright**          | OFL-1.1 | GB18030 | 基于 JetBrains Mono，中文优化 |
