# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Replace 'Noto Sans CJK JP' with the name of a CJK-supported font on your system.
# For example, on Windows, you might use 'Microsoft YaHei'.
# Chinese Japanese and Korean fonts are supported by default in matplotlib.
font_properties = font_manager.FontProperties(family='Noto Sans CJK CN')

plt.title("测试", fontproperties=font_properties)
plt.xlabel("测试", fontproperties=font_properties)
plt.ylabel("测试", fontproperties=font_properties)
plt.plot([1, 2, 3])
plt.show()
# Out:
# findfont: Font family 'Noto Sans CJK CN' not found.
# findfont: Font family 'Noto Sans CJK CN' not found.
# /home/gao/.positron-server/bin/f3aae65e0a1a11d39226cd884520f49301daef82/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/pylabtools.py:152: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/gao/.positron-server/bin/f3aae65e0a1a11d39226cd884520f49301daef82/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/pylabtools.py:152: UserWarning: Glyph 35797 (\N{CJK UNIFIED IDEOGRAPH-8BD5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Noto Sans CJK CN' not found.
# findfont: Font family 'Noto Sans CJK CN' not found.
# findfont: Font family 'Noto Sans CJK CN' not found.
# findfont: Font family 'Noto Sans CJK CN' not found.
# findfont: Font family 'Noto Sans CJK CN' not found.

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# Replace 'Noto Sans CJK JP' with the name of a CJK-supported font on your system.
# For example, on Windows, you might use 'Microsoft YaHei'.
# Chinese Japanese and Korean fonts are supported by default in matplotlib.
font_properties = font_manager.FontProperties(family='Microsoft YaHei')

plt.title("测试", fontproperties=font_properties)
plt.xlabel("测试", fontproperties=font_properties)
plt.ylabel("测试", fontproperties=font_properties)
plt.plot([1, 2, 3])
plt.show()

# %%
plt.rcParams['font.sans-serif'] = 'SimHei'     # 用来正常显示中文标签  中易黑体 office 捆绑,也有版权
# font_properties = font_manager.FontProperties(family='Microsoft YaHei') # 用来正常显示中文标签     2 选 1
# 都是商业字体
# missing from font(s) DejaVu Sans. fig.canvas.print_figure(bytes_io, **kw)  , 如果没有上句, 无法显示中文

# %% [markdown]
# 二、开源中文字体列表（2025 更新）
# 1. 黑体 / 无衬线

# %% [markdown]
# | 名称                       | 授权      | 字符集               | 特色                  |
# | ------------------------ | ------- | ----------------- | ------------------- |
# | **思源黑体** Source Han Sans | OFL-1.1 | GB18030 + CJK 全语言 | 7 字重，Adobe + Google |
# | **OPPOSans**             | OFL-1.1 | GB18030           | 屏显优化，圆角人文           |
# | **HarmonyOS Sans**       | OFL-1.1 | GB18030 + 日文      | 华为鸿蒙默认，Cleartype++  |
# | **MiSans**               | OFL-1.1 | GB18030           | 小米 13 默认，10 字重      |
# | **Alibaba PuHuiTi**      | OFL-1.1 | GB18030           | 阿里官方，3 字重           |

# %% [markdown]
# 2. 宋体 / 衬线

# %% [markdown]
# | 名称                        | 授权      | 字符集           | 特色         |
# | ------------------------- | ------- | ------------- | ---------- |
# | **思源宋体** Source Han Serif | OFL-1.1 | GB18030 + CJK | 传统宋体，7 字重  |
# | **ShipinSong**            | OFL-1.1 | GB18030       | 食品包装专用，高易读 |
# | **FandolSong**            | OFL-1.1 | GB18030       | 方正捐赠，古籍常用  |

# %% [markdown]
# 3. 手写 / 艺术

# %% [markdown]
# | 名称                        | 授权      | 字符集     | 特色        |
# | ------------------------- | ------- | ------- | --------- |
# | **MaShanZheng**           | OFL-1.1 | GB2312  | 毛笔招牌风格    |
# | **ZCOOL QingKe HuangYou** | OFL-1.1 | GB2312  | 黄油手写字体    |
# | **LXGW WenKai**           | OFL-1.1 | GB18030 | 开源文楷，毛笔质感 |

# %% [markdown]
# 4. 等宽 / 编程

# %% [markdown]
# | 名称                       | 授权      | 字符集     | 特色                     |
# | ------------------------ | ------- | ------- | ---------------------- |
# | **思源等宽** Source Han Mono | OFL-1.1 | GB18030 | 等宽版思源黑体                |
# | **LXGW Bright**          | OFL-1.1 | GB18030 | 基于 JetBrains Mono，中文优化 |
